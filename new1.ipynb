# %%
x = 24
y=24.
z= 10+8j
n = "Aryan Choudhary"
m = "true"
print(x,type(x),y,type(y),z,type(z),n,type(n),m,type(m))
a = [1, None , 2.4 , "hello" , 6+6j , True]
print(type(a))
print(a[0])
print(a[2])
print(a,type(a))
a[1]="hi"
print(a[1])
print(a)
# Out:
# 24 <class 'int'> 24.0 <class 'float'> (10+8j) <class 'complex'> Aryan Choudhary <class 'str'> true <class 'str'>
# <class 'list'>
# 1
# 2.4
# [1, None, 2.4, 'hello', (6+6j), True] <class 'list'>
# hi
# [1, 'hi', 2.4, 'hello', (6+6j), True]

# %%
x = 24
y=24.
z= 10+8j
n = "Aryan Choudhary"
m = "true"
print(x,type(x),y,type(y),z,type(z),n,type(n),m,type(m))
a = (1, None , 2.4 , "hello" , 6+6j , True)
print(type(a))
print(a[0])
print(a[2])
print(a,type(a))
# Out:
# 24 <class 'int'> 24.0 <class 'float'> (10+8j) <class 'complex'> Aryan Choudhary <class 'str'> true <class 'str'>
# <class 'tuple'>
# 1
# 2.4
# (1, None, 2.4, 'hello', (6+6j), True) <class 'tuple'>

# %%
x = 24
y=24.
z= 10+8j
n = "Aryan Choudhary"
m = "true"
print(x,type(x),y,type(y),z,type(z),n,type(n),m,type(m))
a = {1, None , 2.4 , "hello" , 6+6j , True}
print(a,type(a))
for i in a :
    print(i)

#print(a[0])
#print(a[2])
#print(a,type(a))
# Out:
# 24 <class 'int'> 24.0 <class 'float'> (10+8j) <class 'complex'> Aryan Choudhary <class 'str'> true <class 'str'>
# {None, 1, 2.4, 'hello', (6+6j)} <class 'set'>
# None
# 1
# 2.4
# hello
# (6+6j)

# %%
x = 24
y=24.
z= 10+8j
n = "Aryan Choudhary"
m = "true"
print(x,type(x),y,type(y),z,type(z),n,type(n),m,type(m))
a = {1: "a", 2: "b" , 3: 2 , 4:True }
print(a,type(a))
for i in a :
    print(i)

# %% [markdown]
# python datastructures: list , tuples , sets , dictionaries
# lists--> are heterogenous collection of elements, square braces, changes allowed , mutable, indexing allowed , ordered
# tuple--> are heterogenous collection of elements, paranthesis, changes not allowed ,immutable , indexing allowed , ordered
# set--> undordered , heterogenous , no duplication - only unique elements , indexing not allowed , indexing allowed , ordered
# dictionary : keys-immutable while values-muttable , duplicacy not allowed in keys but allowed in values
