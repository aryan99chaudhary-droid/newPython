# %%
def even(num):
    if num%2==0:
        return True
    else:
        return False

even(24)
# Out:
# True

# %%
even = lambda num: True if num%2==0 else False
even(24)
# Out:
# True

# %%
names = ["John", "Alice", "Bob", "Eve"]
score = [85, 92, 78, 90]
combined = list(zip(names, score))
print(combined)
# Out:
# [('John', 85), ('Alice', 92), ('Bob', 78), ('Eve', 90)]

# %%
print(list(zip("abcde",[1,2,3,4,5],[True,False,True,False,True])))
# Out:
# [('a', 1, True), ('b', 2, False), ('c', 3, True), ('d', 4, False), ('e', 5, True)]

# %%
a,b,c,d = 5
