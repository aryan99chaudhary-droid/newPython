# %%
arr = np.arange(10000)
lst = [x for x in range(10000)]

start = time.time()
lst2 = [x * 2 for x in lst]
end = time.time()
print(end - start)
start1 = time.time()
arr2 = arr * 2
end1 = time.time()
print(end1 - start1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 arr = np.arange(10000)
#       2 lst = [x for x in range(10000)]
#       3
#       4 start = time.time()
#
# NameError: name 'np' is not defined
