# %% [markdown]
# . Numpy is one of the most important foundation packages for numerical computing in python .
# . It is an open source Python library thats widely used in science and engineering .
# . The numpy library contains multidimensional struture data array , such as the homogenous , N dimensional ndarray and a large library of function that operate efficiently on these data structures .

# %%
twoD = np.arra

# %% [markdown]
# Why not pYTHIN IS Built data structue
# . A python
