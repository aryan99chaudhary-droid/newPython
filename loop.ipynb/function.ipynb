# %%
def sum(a,b):
    return a + b
a=int(input("Enter first number: "))
b=int(input("Enter second number: "))
result=sum(a,b)
print("The sum of", a, "and", b, "is:", result)
# Out:
# The sum of 5 and 7 is: 12

# %%
def even_odd(num):
    if num % 2 == 0:
        return "Even"
    else:
        return "Odd";

# %%
def arof_circle(r, pi=3.14):
    return pi * r * r
r=int(input("Enter the radius of the circle: "))
area= arof_circle(r)
print("The area of the circle with radius", r, "is:", area)
# Out:
# The area of the circle with radius 2 is: 12.56

# %%
def division(a,b):
    if b!=0:
        return (a/b,a//b)
    else:
        print("error:division by zero")
a=float(input("Enter first number: "))
b=float(input("Enter second number: "))
result=division(a,b)
print(result)
print(type(result))
# Out:
# (1.6666666666666667, 1.0)
# <class 'tuple'>

# %%
x = 1,2,3,4,5
print(x)
print(type(x))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>

# %% [markdown]
# in python functions can return multiple values

# %%
write a program using function to generate perfect numbers between 1 to 1000.

# %%
def convert_temperature(temp,unit):
    if unit == "C":
        return (temp * 9/5) + 32
    elif unit == "F":
        return (temp - 32) * 5/9
    else:
        return "Invalid unit"
print(convert_temperature(100,"C"))
print(convert_temperature(212,"F"))
# Out:
# 212.0
# 100.0

# %%
def calculate_total_cost(cart):
    total_cost = 0
    for item in cart:
        price = item['price']
        quantity = item['quantity']
        tax_rate = item['tax_rate']
        total_cost += calculate_item_cost(price, quantity, tax_rate)
    return total_cost

# %% [markdown]
# Lambda - LAmbda functions are small anonymous functions defined using the lambda keywords . They can ahve any number of arguments but one expression . they are commonly used for short operations
