# %%
a = 10
b = 20
print(a)
print(not a)
# Out:
# 10
# False

# %%
a = 10
b = 20
c = 15
print(id(a))
print(id(b))
print(id(c))
# Out:
# 140725896725912
# 140725896726232
# 140725896726072

# %%
arr = ['dog', 'cat', 'bat']
'cat' in arr
# Out:
# True

# %% [markdown]
# VARIOUS TYPES OF OPERATORS-->
# 1. Arithemaic
# 2. Comparision
# 3. Assignment
# 4. Logical
# 5. Bitwise
# 6. Identity and Membership
